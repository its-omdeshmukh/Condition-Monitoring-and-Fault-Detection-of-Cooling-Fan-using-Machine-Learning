# %% [markdown]
# <a href="https://colab.research.google.com/github/its-omdeshmukh/Group_ID_-28-_ML_Model/blob/main/Group_ID_(28)_ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset from CSV file
df = pd.read_csv("/content/gdrive/MyDrive/Chaitrali/Custom Data - 2023-03-31 - Recording 1 - Custom Data - 2023-03-31 - Recording 1 - Custom Data - 2023-03-31 - Recording 1 - Custom Data - 2023-03-31 - Recording 1.csv")

# %%
print(df.head())
# Out:
#    Accleration1  Acceleration2
# 0           334            322
# 1           340            314
# 2           343            294
# 3           352            275
# 4           312            301

# %%
print(df.tail())
# Out:
#      Accleration1  Acceleration2
# 583           328            322
# 584           325            332
# 585           350            337
# 586           348            302
# 587           341            300

# %%
print(df.describe())
# Out:
#        Accleration1  Acceleration2
# count    588.000000     588.000000
# mean     318.918367     319.188776
# std       19.038027      20.253001
# min      266.000000     261.000000
# 25%      304.000000     305.000000
# 50%      319.000000     321.000000
# 75%      333.250000     335.000000
# max      374.000000     370.000000

# %%
col = df['Accleration1'] 
print(col)
# Out:
# 0      334
# 1      340
# 2      343
# 3      352
# 4      312
#       ...
# 583    328
# 584    325
# 585    350
# 586    348
# 587    341
# Name: Accleration1, Length: 588, dtype: int64

# %%
df[['Accleration1', 'Acceleration2']].values
# Out:
# array([[334, 322],
#        [340, 314],
#        [343, 294],
#        ...,
#        [350, 337],
#        [348, 302],
#        [341, 300]])

# %%
arr = df[['Accleration1', 'Acceleration2']].values

# %%
print(arr.shape)
# Out:
# (588, 2)

# %%
plt.scatter(df['Accleration1'], df['Acceleration2'])
plt.xlabel('Accleration1')
plt.ylabel('Accleration2')
# Out:
# Text(0, 0.5, 'Accleration2')

# %%
sns.pairplot(df, x_vars=['Accleration1', 'Acceleration2'], y_vars=['Accleration1', 'Acceleration2'], height=5, aspect=0.8)
plt.show()

# %%
# Split the dataset into training and testing sets
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train the linear regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import r2_score

# %%
# Evaluate the model on the testing set
y_pred = regressor.predict(X_test)
score = r2_score(y_test, y_pred)
print("Model score:", score)
# Out:
# Model score: -0.2688169704448966

# %%
# Evaluate the model on the testing set
y_pred = regressor.predict(X_test)
score = regressor.score(X_test, y_test)
print("Model score:", score)
# Out:
# Model score: -0.06434510851895969

# %%
# Visualize the model performance
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()
